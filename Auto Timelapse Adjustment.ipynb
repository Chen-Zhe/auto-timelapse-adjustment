# %%
import rpa as r

r.init(visual_automation = True, chrome_browser = False)
r.debug(False)
# Out:
# False

# %%
r.wait(2)
r.mouse_x(), r.mouse_y()
# Out:
# (924, 2077)

# %%
# unfortunately OCR is not the most reliable method in the world
x1, y1, x2, y2 = photo_metadata_location
r.read(x1, y1, x2, y2)
# Out:
# '640 1/2505 f/5.6'

# %%
photo_metadata_location = (656, 2051, 924, 2076)
photo_exposure_box_location = (517, 805)

# %%
import math
class ExposureSetting:
  def __init__(self, iso, shutter_speed, aperture, exposure_compensation):
    self.iso = iso
    self.shutter_speed = shutter_speed
    self.aperture = aperture
    self.exposure_compensation = exposure_compensation
    
  def __sub__(self, other):
    iso_stop_diff = round(math.log(self.iso / other.iso, 2) * 3, 0) / 3 # remove *3 and /3 if you have ISO speed that is not aligned to 1/3 stops
    shutter_speed_stop_diff = round(math.log(self.shutter_speed / other.shutter_speed, 2), 2)
    aperture_stop_diff = round(math.log(other.aperture / self.aperture, 2) * 2, 0)
    exp_comp_stop_diff = self.exposure_compensation - other.exposure_compensation
    return round(iso_stop_diff + shutter_speed_stop_diff + aperture_stop_diff + exp_comp_stop_diff, 2)
  
  def __str__(self):
    return f"ISO {self.iso} {round(self.shutter_speed, 5)}s f/{self.aperture} exp.comp.{self.exposure_compensation}"

def interpret_photo_ocr_string(ocr_string):
  # 640 0.55 f/5(s misrecognized)
  metadata = ocr_string.split(" ")
  
  iso_str = metadata[0]
  shutter_speed_str = metadata[1][:-1] # remove "s"
  aperture_str = metadata[2][2:] # remove "f/"
  
  return interpret_photo_metadata(iso_str, shutter_speed_str, aperture_str, "0.0")


def interpret_photo_metadata(iso_str, shutter_speed_str, aperture_str, exposure_comp_str): 
  ss_div_sign_idx = shutter_speed_str.find("/")
  
  if ss_div_sign_idx != -1:
    shutter_speed = 1 / int(shutter_speed_str[ss_div_sign_idx+1:])
  else:
    shutter_speed = float(shutter_speed_str)
    
  return ExposureSetting(int(iso_str), shutter_speed, float(aperture_str), float(exposure_comp_str))

def interpret_user_input(prompt_start_str):
  iso, ss, aperture, exp_comp = input(f"{prompt_start_str} photo settings in 'iso ss aperture exp.comp.':").split()
  return interpret_photo_metadata(iso, ss, aperture, exp_comp)

# %%
start_index = int(input("Start photo index:"))
start_exposure = interpret_user_input("Start")
end_index = input("End photo index:")
end_exposure = interpret_user_input("End")
# Out:
# Start photo index: 4359
# Start photo settings in 'iso ss aperture exp.comp.': 640 1/250 7.1 0.2
# End photo index: 4622
# End photo settings in 'iso ss aperture exp.comp.': 640 1/4 5.6 -0.3

# %%
# interactive adjustment solver
total_num_adjustments = int(end_index) - int(start_index)
total_exp_comp_perc_need = int((end_exposure - start_exposure) * 100)

solved_adjustments = [total_num_adjustments, 0, 0, 0, 0]

def sum_adjustments(adjustments):
  sum_val = 0
  for idx, count in enumerate(adjustments):
    sum_val += (idx + 1) * count
  return sum_val

while True:
  print("Current Solution")
  for idx, count in enumerate(solved_adjustments):
    print(f"{idx + 1}%\t{count}")
  
  try:
    human_idx, value = input("Set index value 'index value': ").split()
    idx = int(human_idx) - 1
    value = int(value)
  except KeyboardInterrupt:
    print("Solver aborted!")
    break
  except:
    print("Invalid input!")
    continue
  
  if value < 0 or idx >= len(solved_adjustments) or idx <= 0:
    print("Invalid input!")
    continue
  
  first_value = solved_adjustments[0] -(value - solved_adjustments[idx])
  if first_value < 0:
    print("Input too large!")
    continue
  
  solved_adjustments[0] = first_value
  solved_adjustments[idx] = value
  
  adjustment_diff = sum_adjustments(solved_adjustments) - total_exp_comp_perc_need
  
  if adjustment_diff == 0:
    if input("Solution accepted. Satisfied?[y/n]").lower() == "y":
      break
    else:
      print("Solution not confirmed. You can continue to make adjustments")
  else:
    print("Solution incomplete. Please continue.")
    
    if adjustment_diff > 0:
      advice = "Reduce the number of images for the larger adjustment steps"
    else:
      advice = "Increase the number of images for the larger adjustment steps"
    
    print(f"Current diff = {adjustment_diff}. {advice}")
  
print(f"You've solved the equations! Solution: {solved_adjustments}")
# Out:
# Current Solution
# 1%	263
# 2%	0
# 3%	0
# 4%	0
# 5%	0
# Set index value 'index value':  2 80
# Solution incomplete. Please continue.
# Current diff = -274. Increase the number of images for the larger adjustment steps
# Current Solution
# 1%	183
# 2%	80
# 3%	0
# 4%	0
# 5%	0
# Set index value 'index value':  3 77
# Solution incomplete. Please continue.
# Current diff = -120. Increase the number of images for the larger adjustment steps
# Current Solution
# 1%	106
# 2%	80
# 3%	77
# 4%	0
# 5%	0
# Set index value 'index value':  4 40
# Solution accepted. Satisfied?[y/n] y
# You've solved the equations! Solution: [66, 80, 77, 40, 0]

# %%
# control how to apply the adjustment
adjustment_symmetry_start_end = (3, 4) # 1-based indexing

adjustment_schedule = [None] * (len(solved_adjustments)
                             + (adjustment_symmetry_start_end[1]
                             - adjustment_symmetry_start_end[0] + 1))

# transform solved adjustments into a schedule

for i in range(len(solved_adjustments)):
  if adjustment_symmetry_start_end[0] - 1 <= i <= adjustment_symmetry_start_end[1] - 1:
    half_value = solved_adjustments[i] // 2
    adjustment_schedule[i] = (i + 1, half_value)
    adjustment_schedule[(len(solved_adjustments) - 1) * 2 - i] = (i + 1, solved_adjustments[i] - half_value)
  else:
    adjustment_schedule[i] = (i + 1, solved_adjustments[i])

print("final adjustment schedule:", adjustment_schedule)
# Out:
# final adjustment schedule: [(1, 66), (2, 80), (3, 38), (4, 20), (5, 0), (4, 20), (3, 39)]

# %%
print("You have 2 seconds to put Capture One window in focus...")

r.wait(2)

print("Start working!")

accumulated_adjustment = 0

for percent_increment, count in adjustment_schedule:
  for _ in range(count):
    # OCR and interpret photo setting
    x1, y1, x2, y2 = photo_metadata_location
    current_photo_exposure = interpret_photo_ocr_string(r.read(x1, y1, x2, y2))
    
    # make adjustment based on accumulator
    x, y = photo_exposure_box_location
    r.click(x, y)
    
    adjust_exp_percentage = int((start_exposure - current_photo_exposure) * 100) + accumulated_adjustment
    if adjust_exp_percentage >= 0:
      sign = ""
    else:
      sign = "-"
      adjust_exp_percentage = -adjust_exp_percentage
    
    adjustment_string = f"{sign}{adjust_exp_percentage//100}.{adjust_exp_percentage%100:02}"
    
    print(current_photo_exposure, "edit exp comp to", adjustment_string)

    r.keyboard(f'{adjustment_string}[enter]')
    
    # accumulate
    accumulated_adjustment += percent_increment
    
    # next photo
    r.keyboard('[ctrl][right]')
# Out:
# You have 2 seconds to put Capture One window in focus...
# Start working!
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.20
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.22
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.23
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.24
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.26
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.27
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.28
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.29
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.30
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.31
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.32
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.34
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.35
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.36
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.37
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.38
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.39
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.40
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.41
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.42
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.43
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.44
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.45
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.46
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.47
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.48
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.49
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.50
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.51
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.52
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.53
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.54
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.55
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.56
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.57
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.58
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.59
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.60
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.61
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.62
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.63
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.64
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.65
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.66
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.67
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.68
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.69
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.70
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.71
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.72
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.73
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.74
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.75
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.76
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.77
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.78
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.79
# ISO 640 0.004s f/7.1 exp.comp.0.0 edit exp comp to 0.80
# ISO 640 0.004s f/6.4 exp.comp.0.0 edit exp comp to 0.48
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.15
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.16
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.17
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.18
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.19
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.23
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.27
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.29
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.31
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.35
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.37
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.39
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.41
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.43
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.45
# ISO 640 0.004s f/5.6 exp.comp.0.0 edit exp comp to 0.47
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.16
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.18
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.20
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.22
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.24
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.26
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.28
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.30
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.32
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.34
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.36
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.38
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.40
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.42
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.44
# ISO 640 0.00556s f/5.6 exp.comp.0.0 edit exp comp to 0.46
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.19
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.17
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.15
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.13
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.11
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.09
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.07
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.05
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.03
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to -0.01
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.01
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.03
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.05
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.07
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.09
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.11
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.13
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.15
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.17
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.19
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.23
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.27
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.29
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.31
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.008s f/5.6 exp.comp.0.0 edit exp comp to 0.35
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.63
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.61
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.59
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.57
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.55
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.53
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.51
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.49
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.47
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.45
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.43
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.41
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.39
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.37
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.35
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.33
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.31
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.29
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.27
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.25
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.23
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.21
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.18
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.15
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.12
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.09
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.06
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to -0.03
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.00
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.03
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.06
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.09
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.88
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.15
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.18
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.24
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.27
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.30
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.36
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.39
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.42
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.45
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.48
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.51
# ISO 640 0.01667s f/5.6 exp.comp.0.0 edit exp comp to 0.54
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.43
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.40
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.37
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.34
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.31
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.28
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.25
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.22
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.19
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.16
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.13
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.10
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.07
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to -0.03
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.01
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.05
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.09
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.13
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.17
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.29
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.37
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.41
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.45
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.49
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.53
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.57
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.61
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.65
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.69
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.73
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.77
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.81
# ISO 640 0.03333s f/5.6 exp.comp.0.0 edit exp comp to 0.85
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to -0.11
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to -0.07
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to -0.03
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.01
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.05
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.09
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.13
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.17
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.21
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.29
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.33
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.37
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.41
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.45
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.49
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.53
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.56
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.59
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.62
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.65
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.68
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.71
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.74
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.77
# ISO 640 0.06667s f/5.6 exp.comp.0.0 edit exp comp to 0.80
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.17
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.14
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.11
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.08
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.05
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to -0.02
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.01
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.04
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.07
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.10
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.13
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.16
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.19
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.22
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.25
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.28
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.31
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.34
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.37
# ISO 640 0.125s f/5.6 exp.comp.0.0 edit exp comp to 0.40
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.57
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.54
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.51
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.48
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.45
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.42
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.39
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.36
# ISO 640 0.25s f/5.6 exp.comp.0.0 edit exp comp to -0.33

# %%
r.close()
# Out:
# True
